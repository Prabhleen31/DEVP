# %%
import pandas as pd

# Load the CSV file into a pandas dataframe
df = pd.read_csv(r"C:\Users\Prabhleen Kaur Pahwa\Documents\1_FORE\Term 3\MLP\KHOJI DATA_FINAL.csv", encoding='cp1252')

# Print the dataframe
pd.DataFrame(df)
# Out:
#    (Parent) ASIN (Child) ASIN            Class  \
# 0     B07DLYQ5TS   B07DLYQ5TS     Hanging Pots
# 1     B07DLYQ5TR   B07DLYQ5TR     Hanging Pots
# 2     B07DLWZML2   B07DLWZML2     Hanging Pots
# 3     B083RBW381   B083RBW381     Hanging Pots
# 4     B08CY32Q45   B08CY32Q45         Planters
# ..           ...          ...              ...
# 86    B08HFGFYS9   B08HFGFYS9         Planters
# 87    B08PVN75F6   B08PVN75F6         Planters
# 88    B08PW58349   B08PW58349             Tray
# 89    B0951WYPGG   B0951WYPGG         Planters
# 90    B096QC9M8T   B096QC9M8T  Decorative Pots
#
#                                   Title            SKU Sessions - Total  \
# 0                           Diamond (5)   OJ-GDWE-6XI9           13,927
# 1                        Orchid (Black)     Pots_00020            8,417
# 2                     Glory Railing (6)     Pots_00007            8,466
# 3                  Double Hook Railing      Pots_00054            7,844
# ...

# %%
df1= df.groupby('Class')[['Units Ordered', 'Units Ordered - B2B']].sum()
df1
# Out:
#                  Units Ordered  Units Ordered - B2B
# Class
# Decorative Pots            130                    3
# Hanging Pots              2478                   57
# Planters                  1287                   46
# Tray                       292                    7
# Water Can                   94                    0

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation

# %%
pip install bar_chart_race
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cols = ['Class', 'Units Ordered', 'Units Ordered - B2B']
subsetdf = df[cols]
subsetdf
# Out:
#               Class  Units Ordered  Units Ordered - B2B
# 0      Hanging Pots            585                    7
# 1      Hanging Pots            445                   11
# 2      Hanging Pots            379                    3
# 3      Hanging Pots            330                   13
# 4          Planters            349                   12
# ..              ...            ...                  ...
# 86         Planters              1                    0
# 87         Planters              1                    0
# 88             Tray              1                    0
# 89         Planters              1                    0
# 90  Decorative Pots              1                    0
#
# [91 rows x 3 columns]

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df=df1, filename=None, n_bars=10, steps_per_period=100, period_length=500, figsize = (4, 2), title='Class wise yearly orders')
# Out:
# C:\Users\Prabhleen Kaur Pahwa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\Prabhleen Kaur Pahwa\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="704" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
